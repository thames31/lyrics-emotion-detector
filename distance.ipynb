# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
import numpy as np

# %%
en_songs = pd.read_csv('data/en_songs3.csv')
en_songs.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0                track_id  \
# 0             0           0  004s3t0ONYlzxII9PLgU6z
# 1             1           1  00chLpzhgVjxs1zKC9UScL
# 2             2           2  00cqd6ZsSkLZqGMlQCR0Zo
# 3             3           3  00emjlCv9azBN0fzuuyLqy
# 4             4           4  00f9VGHfQhAHMCQ2bSjg3D
#
#                                           track_name    track_artist  \
# 0                                       I Feel Alive   Steady Rollin
# 1                                             Poison  Bell Biv DeVoe
# 2  Baby It's Cold Outside (feat. Christina Aguilera)     CeeLo Green
# 3                                         Dumb Litty            KARD
# 4                                            Soldier        James TW
#
#                                               lyrics  track_popularity  \
# 0  trees singing wind sky blue angels smiled saw ...                28
# 1  na yeah spyderman freeze full effect uh huh re...                 0
# 2  really stay baby cold outside got go away baby...                41
# 3  get business keep turning witness criminal fee...                65
# 4  hold breath look keep trying darling okay scar...                70
#
#            track_album_id                      track_album_name  \
# 0  3z04Lb9Dsilqw68SHt6jLB                           Love & Loss
# 1  6oZ6brjB8x3GoeSYdwJdPc                                  Gold
# 2  3ssspRe42CXkhPxdc12xcp                  CeeLo's Magic Moment
# 3  7h5X3xhh3peIK9Y0qI5hbK  KARD 2nd Digital Single ‘Dumb Litty’
# 4  3GNzXsFbzdwM0WKCZtgeNP                              Chapters
#
#   track_album_release_date  ... mode speechiness acousticness  \
# 0               2017-11-21  ...    1      0.0442      0.01170
# 1               2005-01-01  ...    0      0.2160      0.00432
# 2               2012-10-29  ...    0      0.0341      0.68900
# 3               2019-09-22  ...    1      0.0409      0.03700
# 4               2019-04-26  ...    1      0.0550      0.28000
#
#   instrumentalness  liveness  valence    tempo  duration_ms  language  \
# 0          0.00994    0.3470    0.404  135.225       373512        en
# 1          0.00723    0.4890    0.650  111.904       262467        en
# 2          0.00000    0.0664    0.405  118.593       243067        en
# 3          0.00000    0.1380    0.240  130.018       193160        en
# 4          0.00000    0.0975    0.305  147.764       224720        en
#
#    cluster_label
# 0              2
# 1              1
# 2              0
# 3              1
# 4              2
#
# [5 rows x 28 columns]

# %%
df = en_songs.loc[:, en_songs.columns.intersection(['track_artist','track_name','danceability','energy', 'speechiness', 'acousticness', 'duration_ms', 'tempo', 'instrumentalness', 'cluster_label'])]
df
# Out:
#                                               track_name  \
# 0                                           I Feel Alive
# 1                                                 Poison
# 2      Baby It's Cold Outside (feat. Christina Aguilera)
# 3                                             Dumb Litty
# 4                                                Soldier
# ...                                                  ...
# 15400                                           Some Way
# 15401                    Rising Like The Sun - Radio Mix
# 15402                                           Anaconda
# 15403                                              Bound
# 15404             I'll Do 4 U (Re-Recorded / Remastered)
#
#                    track_artist  danceability  energy  speechiness  \
# 0                 Steady Rollin         0.303   0.880       0.0442
# 1                Bell Biv DeVoe         0.845   0.652       0.2160
# 2                   CeeLo Green         0.425   0.378       0.0341
# 3                          KARD         0.760   0.887       0.0409
# 4                      James TW         0.496   0.639       0.0550
# ...                         ...           ...     ...          ...
# 15400                       NAV         0.744   0.715       0.3510
# 15401                   Qulinez         0.479   0.800       0.0878
# 15402               Nicki Minaj         0.963   0.603       0.1800
# 15403  Ponderosa Twins Plus One         0.458   0.540       0.0270
# 15404                 Father MC         0.832   0.666       0.0633
#
#        acousticness  instrumentalness    tempo  duration_ms  cluster_label
# 0           0.01170          0.009940  135.225       373512              2
# 1           0.00432          0.007230  111.904       262467              1
# 2           0.68900          0.000000  118.593       243067              0
# 3           0.03700          0.000000  130.018       193160              1
# 4           0.28000          0.000000  147.764       224720              2
# ...             ...               ...      ...          ...            ...
# 15400       0.10100          0.000000  154.962       179773              3
# 15401       0.00555          0.000000  128.012       208656              2
# 15402       0.06730          0.000006  129.990       260240              3
# 15403       0.71500          0.000428  142.218       191205              0
# 15404       0.14300          0.000000  109.536       223890              5
#
# [15405 rows x 10 columns]

# %%
en_songs[en_songs.track_name=='Night Shift']
# Out:
#        Unnamed: 0.1  Unnamed: 0                track_id   track_name  \
# 11270         11270       11270  5rrgrV39SifIwb4Az0RDsn  Night Shift
#
#       track_artist                                             lyrics  \
# 11270         Juze  dancing dark move something natural play pause...
#
#        track_popularity          track_album_id track_album_name  \
# 11270                36  1AxOZyqOGAlJZbpa8RfD0M      Night Shift
#
#       track_album_release_date  ... mode speechiness acousticness  \
# 11270               2019-06-14  ...    0      0.0395       0.0353
#
#       instrumentalness  liveness  valence    tempo  duration_ms  language  \
# 11270          0.00597       0.3    0.699  123.027       193173        en
#
#        cluster_label
# 11270              1
#
# [1 rows x 28 columns]

# %%
from sklearn.metrics import pairwise_distances

# %%
distances = pairwise_distances(df[['danceability', 'energy', 'speechiness', 'acousticness','tempo', 'instrumentalness', 'cluster_label']])

# %%
distances
# Out:
# array([[2.69739830e-06, 2.33504682e+01, 1.67734686e+01, ...,
#         5.37951538e+00, 7.31687715e+00, 2.58702157e+01],
#        [2.33504682e+01, 0.00000000e+00, 6.81880661e+00, ...,
#         1.81968414e+01, 3.03420787e+01, 4.65299803e+00],
#        [1.67734686e+01, 6.81880661e+00, 0.00000000e+00, ...,
#         1.18169148e+01, 2.36255938e+01, 1.03719242e+01],
#        ...,
#        [5.37951538e+00, 1.81968414e+01, 1.18169148e+01, ...,
#         0.00000000e+00, 1.26184746e+01, 2.05525326e+01],
#        [7.31687715e+00, 3.03420787e+01, 2.36255938e+01, ...,
#         1.26184746e+01, 2.69739830e-06, 3.30695839e+01],
#        [2.58702157e+01, 4.65299803e+00, 1.03719242e+01, ...,
#         2.05525326e+01, 3.30695839e+01, 0.00000000e+00]])

# %%
np.fill_diagonal(distances,1000000)

# %%
df = pd.DataFrame(distances, columns=list(en_songs['track_name']))

# %%
df['id'] = en_songs['track_id']
df
# Out:
#          I Feel Alive          Poison  \
# 0      1000000.000000       23.350468
# 1           23.350468  1000000.000000
# 2           16.773469        6.818807
# 3            5.321888       18.116601
# 4           12.545679       35.877062
# ...               ...             ...
# 15400       19.770510       43.104909
# 15401        7.215732       16.144349
# 15402        5.379515       18.196841
# 15403        7.316877       30.342079
# 15404       25.870216        4.652998
#
#        Baby It's Cold Outside (feat. Christina Aguilera)      Dumb Litty  \
# 0                                              16.773469        5.321888
# 1                                               6.818807       18.116601
# 2                                         1000000.000000       11.503351
# 3                                              11.503351  1000000.000000
# 4                                              29.243600       17.779510
# ...                                                  ...             ...
# 15400                                          36.501584       25.026650
# 15401                                           9.662740        2.261361
# 15402                                          11.816915        2.035415
# 15403                                          23.625594       12.268312
# 15404                                          10.371924       20.870508
#
#               Soldier  Satisfy You  Tender Lover  \
# 0           12.545679    48.012448     32.906698
# 1           35.877062    24.670480     10.263542
# 2           29.243600    31.335095     16.907214
# 3           17.779510    42.773527     27.848433
# 4      1000000.000000    60.537596     45.405461
# ...               ...          ...           ...
# 15400        7.279982    67.769522     52.542322
# 15401       19.754597    40.805880     25.730907
# 15402       17.809978    42.837850     27.606412
# 15403        5.912645    54.958245     40.077439
# 15404       38.347261    22.834206      7.080729
#
#        Hide Away (feat. Envy Monroe)  Limestone    Changes  ...  Cold Water  \
# 0                           6.031692  57.293219  24.303490  ...   42.295049
# 1                          18.536854  34.127674   4.079694  ...   18.963958
# 2                          12.479619  40.888949   9.034067  ...   25.680950
# 3                           4.006905  52.159984  19.323265  ...   37.075437
# 4                          18.016847  69.815042  36.774224  ...   54.830855
# ...                              ...        ...        ...  ...         ...
# 15400                      25.043621  76.975277  43.893698  ...   62.052214
# 15401                       3.601435  50.090400  17.166229  ...   35.083586
# 15402                       2.047800  52.015942  18.981298  ...   37.103410
# 15403                      13.220712  64.400386  31.512433  ...   49.290226
# 15404                      20.467147  31.523262   1.582750  ...   17.070456
#
#        OUTTA MY MIND  \
# 0          48.323592
# 1          25.227068
# 2          31.995454
# 3          43.207709
# 4          60.840949
# ...              ...
# 15400      67.994647
# 15401      41.125566
# 15402      43.039834
# 15403      55.450239
# 15404      22.539515
#
#        Bubble Butt (feat. Bruno Mars, 2 Chainz, Tyga & Mystic) - Radio Mix  \
# 0                                              58.841729
# 1                                              82.175398
# 2                                              75.526364
# 3                                              64.069334
# 4                                              46.304179
# ...                                                  ...
# 15400                                          39.093360
# 15401                                          66.051932
# 15402                                          64.065326
# 15403                                          51.930353
# 15404                                          84.543090
#
#        Sick Feeling        Some Way  Rising Like The Sun - Radio Mix  \
# 0         30.595560       19.770510                         7.215732
# 1         53.925431       43.104909                        16.144349
# 2         47.272205       36.501584                         9.662740
# 3         35.817583       25.026650                         2.261361
# 4         18.056503        7.279982                        19.754597
# ...             ...             ...                              ...
# 15400     10.913634  1000000.000000                        26.971436
# 15401     37.807243       26.971436                   1000000.000000
# 15402     35.846464       24.973820                         2.279882
# 15403     23.694781       13.115027                        14.366123
# 15404     56.363739       45.471047                        18.722303
#
#              Anaconda           Bound  I'll Do 4 U (Re-Recorded / Remastered)  \
# 0            5.379515        7.316877                               25.870216
# 1           18.196841       30.342079                                4.652998
# 2           11.816915       23.625594                               10.371924
# 3            2.035415       12.268312                               20.870508
# 4           17.809978        5.912645                               38.347261
# ...               ...             ...                                     ...
# 15400       24.973820       13.115027                               45.471047
# 15401        2.279882       14.366123                               18.722303
# 15402  1000000.000000       12.618475                               20.552533
# 15403       12.618475  1000000.000000                               33.069584
# 15404       20.552533       33.069584                          1000000.000000
#
#                            id
# 0      004s3t0ONYlzxII9PLgU6z
# 1      00chLpzhgVjxs1zKC9UScL
# 2      00cqd6ZsSkLZqGMlQCR0Zo
# 3      00emjlCv9azBN0fzuuyLqy
# 4      00f9VGHfQhAHMCQ2bSjg3D
# ...                       ...
# 15400  7zxRMhXxJMQCeDDg0rKAVo
# 15401  7zXzWCVuz7whIuYZyEAlxt
# 15402  7zycSpvjDcqh6YT1FEl2kY
# 15403  7zye9v6B785eFWEFYs13C2
# 15404  7zyLObYw4QUKQDyZOb4J0Y
#
# [15405 rows x 15406 columns]

# %%
df = df.set_index('id', drop=True)

# %%
song_name = 'I Feel Alive'
dl = df.sort_values(by=song_name)

# %%
ids = list(dl.head(5).index)

# %%
ids
# Out:
# ['385Urz8Qa8CIcK9tl3SA8g',
#  '6In9ynCY22Ed1YRhpLMZLl',
#  '7ATyLePQnHxFk5kzxWCcsh',
#  '7c8vaoaPChZNEFEPWoAQ4i',
#  '4GetBW8bJ8lB2Y9ugFb30p']

# %%
links = []

for id in ids:
    link = "https://open.spotify.com/track/" + id
    links.append(link)

# %%
links
# Out:
# ['https://open.spotify.com/track/385Urz8Qa8CIcK9tl3SA8g',
#  'https://open.spotify.com/track/6In9ynCY22Ed1YRhpLMZLl',
#  'https://open.spotify.com/track/7ATyLePQnHxFk5kzxWCcsh',
#  'https://open.spotify.com/track/7c8vaoaPChZNEFEPWoAQ4i',
#  'https://open.spotify.com/track/4GetBW8bJ8lB2Y9ugFb30p']
