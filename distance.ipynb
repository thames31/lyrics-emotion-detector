# %%
import pandas as pd
from sklearn.metrics import pairwise_distances
import numpy as np

# %%
en_songs = pd.read_csv('data/en_songs3.csv')
en_songs.head()
# Out:
#                  track_id                                         track_name  \
# 0  004s3t0ONYlzxII9PLgU6z                                       I Feel Alive
# 1  00chLpzhgVjxs1zKC9UScL                                             Poison
# 2  00cqd6ZsSkLZqGMlQCR0Zo  Baby It's Cold Outside (feat. Christina Aguilera)
# 3  00emjlCv9azBN0fzuuyLqy                                         Dumb Litty
# 4  00f9VGHfQhAHMCQ2bSjg3D                                            Soldier
#
#      track_artist                                             lyrics  \
# 0   Steady Rollin  trees singing wind sky blue angels smiled saw ...
# 1  Bell Biv DeVoe  na yeah spyderman freeze full effect uh huh re...
# 2     CeeLo Green  really stay baby cold outside got go away baby...
# 3            KARD  get business keep turning witness criminal fee...
# 4        James TW  hold breath look keep trying darling okay scar...
#
#    track_popularity          track_album_id  \
# 0                28  3z04Lb9Dsilqw68SHt6jLB
# 1                 0  6oZ6brjB8x3GoeSYdwJdPc
# 2                41  3ssspRe42CXkhPxdc12xcp
# 3                65  7h5X3xhh3peIK9Y0qI5hbK
# 4                70  3GNzXsFbzdwM0WKCZtgeNP
#
#                        track_album_name track_album_release_date  \
# 0                           Love & Loss               2017-11-21
# 1                                  Gold               2005-01-01
# 2                  CeeLo's Magic Moment               2012-10-29
# 3  KARD 2nd Digital Single ‘Dumb Litty’               2019-09-22
# 4                              Chapters               2019-04-26
#
#                                        playlist_name             playlist_id  \
# 0                                  Hard Rock Workout  3YouF0u7waJnolytf9JCXf
# 1  Back in the day - R&B, New Jack Swing, Swingbe...  3a9y4eeCJRmG9p4YKfqYIx
# 2                                     Christmas Soul  6FZYc2BvF7tColxO8PBShV
# 3                                  K-Party Dance Mix  37i9dQZF1DX4RDXswvP6Mj
# 4                                 urban contemporary  4WiB26kw0INKwbzfb5M6Tv
#
#    ... mode speechiness  acousticness  instrumentalness  liveness  valence  \
# 0  ...    1      0.0442       0.01170           0.00994    0.3470    0.404
# 1  ...    0      0.2160       0.00432           0.00723    0.4890    0.650
# 2  ...    0      0.0341       0.68900           0.00000    0.0664    0.405
# 3  ...    1      0.0409       0.03700           0.00000    0.1380    0.240
# 4  ...    1      0.0550       0.28000           0.00000    0.0975    0.305
#
#      tempo  duration_ms  language  cluster_label
# 0  135.225       373512        en              2
# 1  111.904       262467        en              0
# 2  118.593       243067        en              3
# 3  130.018       193160        en              1
# 4  147.764       224720        en              2
#
# [5 rows x 26 columns]

# %%
df = en_songs.loc[:, en_songs.columns.intersection(['track_artist','track_name','danceability','energy', 'speechiness', 'acousticness', 'duration_ms', 'tempo', 'instrumentalness', 'cluster_label'])]
df
# Out:
#                                               track_name  \
# 0                                           I Feel Alive
# 1                                                 Poison
# 2      Baby It's Cold Outside (feat. Christina Aguilera)
# 3                                             Dumb Litty
# 4                                                Soldier
# ...                                                  ...
# 15400                                           Some Way
# 15401                    Rising Like The Sun - Radio Mix
# 15402                                           Anaconda
# 15403                                              Bound
# 15404             I'll Do 4 U (Re-Recorded / Remastered)
#
#                    track_artist  danceability  energy  speechiness  \
# 0                 Steady Rollin         0.303   0.880       0.0442
# 1                Bell Biv DeVoe         0.845   0.652       0.2160
# 2                   CeeLo Green         0.425   0.378       0.0341
# 3                          KARD         0.760   0.887       0.0409
# 4                      James TW         0.496   0.639       0.0550
# ...                         ...           ...     ...          ...
# 15400                       NAV         0.744   0.715       0.3510
# 15401                   Qulinez         0.479   0.800       0.0878
# 15402               Nicki Minaj         0.963   0.603       0.1800
# 15403  Ponderosa Twins Plus One         0.458   0.540       0.0270
# 15404                 Father MC         0.832   0.666       0.0633
#
#        acousticness  instrumentalness    tempo  duration_ms  cluster_label
# 0           0.01170          0.009940  135.225       373512              2
# 1           0.00432          0.007230  111.904       262467              0
# 2           0.68900          0.000000  118.593       243067              3
# 3           0.03700          0.000000  130.018       193160              1
# 4           0.28000          0.000000  147.764       224720              2
# ...             ...               ...      ...          ...            ...
# 15400       0.10100          0.000000  154.962       179773              0
# 15401       0.00555          0.000000  128.012       208656              2
# 15402       0.06730          0.000006  129.990       260240              1
# 15403       0.71500          0.000428  142.218       191205              3
# 15404       0.14300          0.000000  109.536       223890              5
#
# [15405 rows x 10 columns]

# %%
en_songs[en_songs.track_name=='Night Shift']
# Out:
#                      track_id   track_name track_artist  \
# 11270  5rrgrV39SifIwb4Az0RDsn  Night Shift         Juze
#
#                                                   lyrics  track_popularity  \
# 11270  dancing dark move something natural play pause...                36
#
#                track_album_id track_album_name track_album_release_date  \
# 11270  1AxOZyqOGAlJZbpa8RfD0M      Night Shift               2019-06-14
#
#           playlist_name             playlist_id  ... mode speechiness  \
# 11270  Tropical House 🌴  06zrBJ5cts5aemZmqe80J7  ...    0      0.0395
#
#        acousticness  instrumentalness  liveness  valence    tempo  \
# 11270        0.0353           0.00597       0.3    0.699  123.027
#
#        duration_ms  language  cluster_label
# 11270       193173        en              5
#
# [1 rows x 26 columns]

# %%
distances = pairwise_distances(df[['danceability', 'energy', 'speechiness', 'acousticness','tempo', 'instrumentalness', 'cluster_label']])

# %%
distances
# Out:
# array([[2.69739830e-06, 2.34146186e+01, 1.66838020e+01, ...,
#         5.37951538e+00, 7.10891632e+00, 2.58702157e+01],
#        [2.34146186e+01, 0.00000000e+00, 7.38214898e+00, ...,
#         1.81142219e+01, 3.04736237e+01, 5.53627950e+00],
#        [1.66838020e+01, 7.38214898e+00, 0.00000000e+00, ...,
#         1.16034252e+01, 2.36255938e+01, 9.30466607e+00],
#        ...,
#        [5.37951538e+00, 1.81142219e+01, 1.16034252e+01, ...,
#         0.00000000e+00, 1.24187722e+01, 2.08424230e+01],
#        [7.10891632e+00, 3.04736237e+01, 2.36255938e+01, ...,
#         1.24187722e+01, 2.69739830e-06, 3.27505325e+01],
#        [2.58702157e+01, 5.53627950e+00, 9.30466607e+00, ...,
#         2.08424230e+01, 3.27505325e+01, 0.00000000e+00]])

# %%
np.fill_diagonal(distances,1000000)

# %%
df = pd.DataFrame(distances, columns=list(en_songs['track_name']))

# %%
df['id'] = en_songs['track_id']
df
# Out:
#          I Feel Alive          Poison  \
# 0      1000000.000000       23.414619
# 1           23.414619  1000000.000000
# 2           16.683802        7.382149
# 3            5.321888       18.144179
# 4           12.545679       35.918847
# ...               ...             ...
# 15400       19.846236       43.058485
# 15401        7.215732       16.236995
# 15402        5.379515       18.114222
# 15403        7.108916       30.473624
# 15404       25.870216        5.536280
#
#        Baby It's Cold Outside (feat. Christina Aguilera)      Dumb Litty  \
# 0                                              16.683802        5.321888
# 1                                               7.382149       18.144179
# 2                                         1000000.000000       11.633017
# 3                                              11.633017  1000000.000000
# 4                                              29.192261       17.779510
# ...                                                  ...             ...
# 15400                                          36.501584       24.966642
# 15401                                           9.506237        2.261361
# 15402                                          11.603425        0.378042
# 15403                                          23.625594       12.389975
# 15404                                           9.304666       20.870508
#
#               Soldier  Satisfy You  Tender Lover  \
# 0           12.545679    47.981196     32.784917
# 1           35.918847    24.832088      9.504751
# 2           29.192261    31.335095     16.274332
# 3           17.779510    42.808581     27.559667
# 4      1000000.000000    60.512813     45.317280
# ...               ...          ...           ...
# 15400        7.483191    67.769522     52.513766
# 15401       19.754597    40.769104     25.574980
# 15402       17.809978    42.779451     27.533869
# 15403        5.653262    54.958245     39.814584
# 15404       38.347261    22.369643      8.132449
#
#        Hide Away (feat. Envy Monroe)  Limestone    Changes  ...  Cold Water  \
# 0                           5.327411  57.223360  24.138343  ...   42.295049
# 1                          18.127740  33.907199   1.282147  ...   18.990306
# 2                          11.607794  40.631345   7.785523  ...   25.739293
# 3                           0.235132  52.006384  18.904724  ...   37.075437
# 4                          17.793448  69.757724  36.665291  ...   54.830855
# ...                              ...        ...        ...  ...         ...
# 15400                      24.983653  76.955788  43.859511  ...   62.028036
# 15401                       2.229425  50.010480  16.931610  ...   35.083586
# 15402                       0.439868  51.977478  18.875637  ...   37.049467
# 15403                      12.401097  64.237136  31.177451  ...   49.320648
# 15404                      20.854355  31.776030   4.301755  ...   17.070456
#
#        OUTTA MY MIND  \
# 0          48.323592
# 1          25.404822
# 2          31.665582
# 3          43.207709
# 4          60.840949
# ...              ...
# 15400      68.148896
# 15401      41.125566
# 15402      43.179015
# 15403      55.260555
# 15404      22.539515
#
#        Bubble Butt (feat. Bruno Mars, 2 Chainz, Tyga & Mystic) - Radio Mix  \
# 0                                              58.867215
# 1                                              82.151057
# 2                                              75.526364
# 3                                              64.045917
# 4                                              46.336562
# ...                                                  ...
# 15400                                          39.093360
# 15401                                          66.074638
# 15402                                          64.073130
# 15403                                          51.930353
# 15404                                          84.667196
#
#        Sick Feeling        Some Way  Rising Like The Sun - Radio Mix  \
# 0         30.595560       19.846236                         7.215732
# 1         53.953240       43.058485                        16.236995
# 2         47.240464       36.501584                         9.506237
# 3         35.817583       24.966642                         2.261361
# 4         18.056503        7.483191                        19.754597
# ...             ...             ...                              ...
# 15400     11.050222  1000000.000000                        27.026993
# 15401     37.807243       27.026993                   1000000.000000
# 15402     35.846464       24.993833                         2.279882
# 15403     23.631391       13.115027                        14.261329
# 15404     56.363739       45.701380                        18.722303
#
#              Anaconda           Bound  I'll Do 4 U (Re-Recorded / Remastered)  \
# 0            5.379515        7.108916                               25.870216
# 1           18.114222       30.473624                                5.536280
# 2           11.603425       23.625594                                9.304666
# 3            0.378042       12.389975                               20.870508
# 4           17.809978        5.653262                               38.347261
# ...               ...             ...                                     ...
# 15400       24.993833       13.115027                               45.701380
# 15401        2.279882       14.261329                               18.722303
# 15402  1000000.000000       12.418772                               20.842423
# 15403       12.418772  1000000.000000                               32.750532
# 15404       20.842423       32.750532                          1000000.000000
#
#                            id
# 0      004s3t0ONYlzxII9PLgU6z
# 1      00chLpzhgVjxs1zKC9UScL
# 2      00cqd6ZsSkLZqGMlQCR0Zo
# 3      00emjlCv9azBN0fzuuyLqy
# 4      00f9VGHfQhAHMCQ2bSjg3D
# ...                       ...
# 15400  7zxRMhXxJMQCeDDg0rKAVo
# 15401  7zXzWCVuz7whIuYZyEAlxt
# 15402  7zycSpvjDcqh6YT1FEl2kY
# 15403  7zye9v6B785eFWEFYs13C2
# 15404  7zyLObYw4QUKQDyZOb4J0Y
#
# [15405 rows x 15406 columns]

# %%
df = df.set_index('id', drop=True)

# %%
from sklearn.neighbors import BallTree

# %%
btree = BallTree(df, metric='euclidean')

# %%
ids
# Out:
# ['385Urz8Qa8CIcK9tl3SA8g',
#  '6In9ynCY22Ed1YRhpLMZLl',
#  '7ATyLePQnHxFk5kzxWCcsh',
#  '7c8vaoaPChZNEFEPWoAQ4i',
#  '4GetBW8bJ8lB2Y9ugFb30p']

# %%
links = []

for id in ids:
    link = "https://open.spotify.com/track/" + id
    links.append(link)

# %%
links
# Out:
# ['https://open.spotify.com/track/385Urz8Qa8CIcK9tl3SA8g',
#  'https://open.spotify.com/track/6In9ynCY22Ed1YRhpLMZLl',
#  'https://open.spotify.com/track/7ATyLePQnHxFk5kzxWCcsh',
#  'https://open.spotify.com/track/7c8vaoaPChZNEFEPWoAQ4i',
#  'https://open.spotify.com/track/4GetBW8bJ8lB2Y9ugFb30p']
